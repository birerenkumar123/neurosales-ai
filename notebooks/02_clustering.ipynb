# %% [markdown]
# # Customer Segmentation / Clustering Exploration
# Finding VIP customers using K-Means grouping algorithms.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Load clean data
df = pd.read_csv('../data/raw/sales_data.csv')
df['revenue'] = df['quantity'] * df['price']

# Aggregate by Age to find demographic spending blocks
grouped = df.groupby('age').agg({'revenue': 'mean', 'quantity': 'sum'}).reset_index()
grouped.head()

# %%
# K-Means Logic
scaler = StandardScaler()
scaled = scaler.fit_transform(grouped[['revenue', 'quantity']])
km = KMeans(n_clusters=3, random_state=42)
grouped['cluster'] = km.fit_predict(scaled)

plt.scatter(grouped['age'], grouped['revenue'], c=grouped['cluster'], cmap='viridis')
plt.title('Customer Profiles: Revenue vs Age')
plt.show()
